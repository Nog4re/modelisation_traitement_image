# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from multiprocessing import Pool

# %%
from keras.datasets import mnist

# %%
numbers = mnist.load_data()[0][0]

# %%
img = numbers[0]
plt.imshow(img, cmap="gray");

# %%
noisy = img + np.random.normal(scale=32, size=img.shape)
plt.imshow(noisy, cmap="gray");

# %% [markdown]
# # Paramètres

# %%
T2D = lambda x: x
T3D_ht = lambda x: x
T3D_ht_inv = lambda x: x
T3D_wie = lambda x: x
T3D_wie_inv = lambda x: x

N = 7
step = 2

threshold_t2d_ht = 32
threshold_dist_set = 15
threshold_t3d_ht = 32

sigma_ht = 1
sigma_wie = 1

# %% [markdown]
# # Fonctions

# %%
def generate_block(img, x, N=N):
    
    ret = np.zeros((N,N))
    
    x_min = max(0, x[0])
    y_min = max(0, x[1])

    x_max = min(x[0]+N, img.shape[0])
    y_max = min(x[1]+N, img.shape[1])

    ret[x_min-x[0]:x_max-x[0], y_min-x[1]:y_max-x[1]] = img[x_min:x_max, y_min:y_max]
    
    return ret

# %%
def dist(img1, img2, transfo_2D, threshold=None, N=N):
    
    T1 = transfo_2D(img1).copy()
    T2 = transfo_2D(img2).copy()
    
    if not threshold == None:
        T1[T1 < threshold] = 0
        T2[T2 < threshold] = 0

    return np.linalg.norm(T1 - T2)**2 / N**2

# %%
def calculate_dist(x, block_ref, img, threshold_dist, T2D=T2D, dist_func=dist, N=N):
    
    block = generate_block(img, x, N)
    
    return dist_func(block_ref, block, T2D, threshold=threshold_dist)

# %%
def create_set(xR, img, dist_func=dist, threshold_dist=threshold_t2d_ht, thresh_dist_set=threshold_dist_set, nmax=None, neighborhood=neighborhood, N=N):

    x_min = max(xR[0]-neighborhood, -N+1)
    y_min = max(xR[1]-neighborhood, -N+1)
    
    x_max = min(xR[0]+neighborhood, img.shape[0])
    y_max = min(xR[1]+neighborhood, img.shape[0])

    block_ref = generate_block(img, xR)
    
    xs = [(np.array([i, j]), block_ref, img, threshold_dist) for i in range(x_min, x_max) for j in range(y_min, y_max)]
    
    with Pool() as pool:
        dists = pool.starmap(calculate_dist, xs)
                
    set_xR = []
    
    if nmax == None:
        nmax = len(dists)
    
    for i in np.argsort(dists)[:nmax]:
        if dists[i] <= thresh_dist_set:
            set_xR.append(xs[i])
        
    return set_xR

# %%
def stack(ens, img):
    
    ret = [generate_block(img, x) for x in ens]
    ret = np.stack(ret, axis=2)
    
    return ret

# %%
def transform_3D_ht(Z, w, threshold=threshold_t3d_ht, T3D=T3D_ht, T3D_inv=T3D_ht_inv):
    
    # For symmetry with transform_3D_wie
    w = None
    
    T = T3D(Z).copy()
    T[T < threshold] = 0
    
    return T3D_inv(T)

# %%
def generate_weights_ht(xRs, noisy, nmax_set=None, sigma=sigma_ht):
    
    weights = []
    sets = []
    
    print(" - ", end="")
    
    for i, xR in enumerate(xRs):
        
        S = create_set(xR, noisy, nmax=nmax_set)
        Z = stack(S, noisy)
        sets.append(S)
        
        Y_hat = transform_3D_ht(Z, None)
        nz = np.count_nonzero(Y_hat)
        
        if nz == 0:
            weights.append(1)
        else:
            weights.append(1/(sigma**2 * nz))
            
        print(f" - Génération des sets ht : {i+1} / {len(xRs)}", end='\r')
            
    print("")
            
    return weights, sets

# %%
def aggregation(xRs, img, weights, sets, transform_3D, N=N):
    
    height, width = img.shape
    
    num = np.zeros_like(img)
    den = np.zeros_like(img)
    
    current_pixel = 1
    
    print(" - ", end="")
    
    for w, xR, S in zip(weights, xRs, sets):
        
        Y_hat = transform_3D(stack(S, img), w)
        
        #print(xR, len(S))
        
        for i in range(xR[0], min(xR[0]+N, height)):
            for j in range(xR[1], min(xR[1]+N, width)):
                
                num[i,j] += Y_hat[i-xR[0],j-xR[1],:].sum() * w
                
                for x in S:
                    if (i >= x[0] and i < x[0]+N) and (j >= x[1] and j < x[1]+N):
                        den[i,j] += w
        
        print(f" - Aggrégation : {current_pixel} / {len(xRs)}", end='\r')
        
        current_pixel += 1
                        
    print("")
    
    return num, den

# %%
def recreate_basic(xRs, noisy, nmax_set=None):
    
    weights, sets = generate_weights_ht(xRs, noisy, nmax_set=nmax_set)
    
    num, den = aggregation(xRs, noisy, weights, sets, transform_3D_ht)
    
    den[den==0] = 1
    y = num/den
    
    y = y.clip(max=y.max()/2)
    y = y / np.max(y) * np.median(noisy)
    
    return y

# %%
def generate_w_wie(xRs, basic, noisy, nmax_set=None, T3D=T3D_wie, sigma=sigma_wie):
    
    Ws = []
    sets = []
    
    print(" - ", end="")
    
    for i, xR in enumerate(xRs):
        
        S = create_set(xR, basic, threshold_dist=None, nmax=nmax_set)
        Y = stack(S, basic)
        sets.append(S)
        
        T = T3D(Y)**2
        W = T**2 / (T**2 + sigma**2)
        
        Ws.append(W)
        
        print(f" - Génération des sets wie : {i+1} / {len(xRs)}", end='\r')
        
    print("")
            
    return Ws, sets

# %%
def transform_3D_wie(Z, W, T3D=T3D_wie, T3D_inv=T3D_wie_inv):
    
    collaborative_filtering = np.multiply(W, T3D(Z))
    
    return T3D_inv(collaborative_filtering)

# %%
def recreate_final(xRs, basic, noisy, nmax_set=None, sigma=sigma_wie):
    
    Ws, sets = generate_w_wie(xRs, basic, noisy, nmax_set=nmax_set, sigma=sigma)
    weights = [1 / (np.linalg.norm(W)**2 * sigma**2) for W in Ws]
    
    num, den = aggregation(xRs, noisy, weights, sets, transform_3D_wie)
    
    den[den==0] = 1
    y = num/den
    
    y = y.clip(max=y.max()/2)
    y = y / np.max(y) * np.median(noisy)
    
    return y

# %%
def algo(xRs, noisy, nmax_set=None):
    
    basic = recreate_basic(xRs, noisy, nmax_set)
    final = recreate_final(xRs, basic, noisy, nmax_set)
    
    return final

# %% [markdown]
# # Tests

# %%
xR = np.array([12, 12])
block = generate_block(img, xR, 10)
plt.imshow(block, cmap="gray");

# %%
xR = np.array([12, 12])
block = generate_block(img, xR)
plt.imshow(block, cmap="gray");

# %%
xR = np.array([12, 12])
x = np.array([24, 26])

block_ref = generate_block(img, xR)
block = generate_block(img, x)

print(dist(block_ref, block, T2D))

plt.subplot(1, 2, 1)
plt.imshow(block_ref, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(block, cmap="gray");
# Out:
# 22229.79591836734

# %%
xR = np.array([12, 12])
x = np.array([19, 15])

block_ref = generate_block(noisy, xR)
block = generate_block(noisy, x)

print(dist(block_ref, block, T2D))

plt.subplot(1, 2, 1)
plt.imshow(block_ref, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(block, cmap="gray");
# Out:
# 25730.52839484705

# %%
xR = np.array([24, 24])
S = create_set(xR, noisy, dist, threshold_dist=64, thresh_dist_set=100, nmax=3)

print(len(S))

block_ref = generate_block(img, xR)
plt.imshow(block_ref, cmap="gray");

# %%
for i, x in enumerate(S):
    block = generate_block(img, x)
    plt.subplot(1, len(S), i+1)
    plt.imshow(block, cmap="gray")
plt.plot();

# %%
for i, x in enumerate(S):
    block = generate_block(noisy, x)
    plt.subplot(1, len(S), i+1)
    plt.imshow(block, cmap="gray")
plt.plot();

# %%
Z = stack(S, noisy)
print(Z.shape)
# Out:
# (128, 128, 3)

# %%
Y_hat = transform_3D_ht(Z, 32)
print(Y_hat.shape)
# Out:
# (128, 128, 3)

# %%
xR = np.array([12, 12])
weights, sets = generate_weights_ht([xR], noisy, nmax_set=10)
# Out:
#  - Génération des sets ht : 1 / 1

# %%
weights, sets
# Out:
# ([6.1042607740202665e-06],
#  [[array([12, 12]),
#    array([14, 12]),
#    array([14, 13]),
#    array([11, 12]),
#    array([13, 12]),
#    array([10, 11]),
#    array([10, 12]),
#    array([ 8, 13]),
#    array([18, 12]),
#    array([16, 11])]])

# %%
num, den = aggregation([xR], noisy, weights, sets, transform_3D_ht)
# Out:
#  - Aggrégation : 1 / 1

# %%
xR = np.array([12, 12])
new_image = recreate_basic([xR], noisy, nmax_set=10)
# Out:
#  - Génération des sets ht : 1 / 1
#  - Aggrégation : 1 / 1

# %%
plt.imshow(new_image, cmap="gray");

# %%
xRs = [np.array([i, j]) for i in range(0, img.shape[0], step) for j in range(0, img.shape[1], step)]

# %%
plt.figure(figsize=(15,8))
plt.imshow(noisy, cmap="gray");

# %%
new_image = recreate_basic(xRs, noisy, nmax_set=5)
plt.figure(figsize=(15,8))
plt.imshow(new_image, cmap="gray");
# Out:
# Génération des sets ht : 7 / 256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_628\1363250916.py in <module>
# ----> 1 new_image = recreate_basic(xRs, noisy, nmax_set=1)
#       2 plt.figure(figsize=(15,8))
#       3 plt.imshow(new_image, cmap="gray");
#
# ~\AppData\Local\Temp\ipykernel_628\2910568648.py in recreate_basic(xRs, noisy, nmax_set)
#       1 def recreate_basic(xRs, noisy, nmax_set=None):
#       2
# ----> 3     weights, sets = generate_weights_ht(xRs, noisy, nmax_set=nmax_set)
#       4
#       5     num, den = aggregation(xRs, noisy, weights, sets, transform_3D_ht)
#
# ~\AppData\Local\Temp\ipykernel_628\4195012822.py in generate_weights_ht(xRs, noisy, nmax_set, sigma)
#       8         print(f"Génération des sets ht : {i+1} / {len(xRs)}", end='\r')
#       9
# ---> 10         S = create_set(xR, noisy, dist, nmax=nmax_set)
#      11         Z = stack(S, noisy)
#      12         sets.append(S)
#
# ~\AppData\Local\Temp\ipykernel_628\1169435638.py in create_set(xR, img, dist_func, T2D, threshold_dist, thresh_dist_set, nmax, neighborhood, N)
#      18             block = generate_block(img, x, N)
#      19
# ---> 20             dist = dist_func(block_ref, block, T2D, threshold=threshold_dist)
#      21
#      22             if dist < thresh_dist_set:
#
# ~\AppData\Local\Temp\ipykernel_628\2482005212.py in dist(img1, img2, transfo_2D, threshold, N)
#       8         T2[T2 < threshold] = 0
#       9
# ---> 10     return np.linalg.norm(T1 - T2)**2 / N**2
#
# KeyboardInterrupt:

# %%
xR = np.array([12, 12])
x = np.array([19, 15])

block_ref = generate_block(new_image, xR)
block = generate_block(new_image, x)

print(dist(block_ref, block, lambda x: x))

plt.subplot(1, 2, 1)
plt.imshow(block_ref, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(block, cmap="gray");
# Out:
# 0.02142533895642223

# %%
xR = np.array([12, 12])
generate_w_wie([xR], new_image, noisy, nmax_set=1)
# Out:
#  - Génération des sets wie : 1 / 1
# ([array([[[0.09728284],
#           [0.09728284],
#           [0.09728284],
#           ...,
#           [0.09728284],
#           [0.09728284],
#           [0.09728284]],
#
#          [[0.09728284],
#           [0.09728284],
#           [0.09728284],
#           ...,
#           [0.09728284],
#           [0.09728284],
#           [0.09728284]],
#
#          [[0.09728284],
#           [0.05058851],
#           [0.05004865],
#           ...,
#           [0.09547256],
#           [0.09488494],
#           [0.09728284]],
#
#          ...,
#
#          [[0.09728284],
#           [0.06597798],
#           [0.07930858],
#           ...,
#           [0.05886636],
#           [0.04387224],
#           [0.09728284]],
#
#          [[0.09728284],
#           [0.09728284],
#           [0.09728284],
#           ...,
#           [0.09728284],
#           [0.09728284],
#           [0.09728284]],
#
#          [[0.09728284],
#           [0.09728284],
#           [0.09728284],
#           ...,
#           [0.09728284],
#           [0.09728284],
#           [0.09728284]]])],
#  [[array([12, 12])]])

# %%
xR = np.array([12, 12])
basic_image = recreate_basic([xR], noisy, nmax_set=5)
# Out:
#  - Génération des sets ht : 1 / 1
#  - Aggrégation : 1 / 1

# %%
final_image = recreate_final([xR], basic_image, noisy, nmax_set=5)
# Out:
#  - Génération des sets wie : 1 / 1
#  - Aggrégation : 1 / 1

# %%
plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(generate_block(noisy, xR), cmap="gray")

plt.subplot(1,3,2)
plt.imshow(generate_block(basic_image, xR), cmap="gray")

plt.subplot(1,3,3)
plt.imshow(generate_block(final_image, xR), cmap="gray")

plt.plot();

# %%
xRs = [np.array([i, j]) for i in range(-N+1, img.shape[0], step) for j in range(-N+1, img.shape[1], step)]

# %%
basic = recreate_basic(xRs, noisy)
# Out:
# Génération des sets ht : 51 / 40000

# %%
final = recreate_final(xRs, basic, noisy)

# %%
plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(noisy, cmap="gray")

plt.subplot(1,3,2)
plt.imshow(basic, cmap="gray")

plt.subplot(1,3,3)
plt.imshow(final, cmap="gray")

plt.plot();

# %% [markdown]
# # Algo final

# %%
y = algo(xRs, noisy)

plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(noisy, cmap="gray")

plt.subplot(1,3,2)
plt.imshow(y, cmap="gray")

plt.subplot(1,3,3)
plt.imshow(img, cmap="gray")

plt.plot();

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fe0c1041-c3d0-4be4-979f-88dc2a688327' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
